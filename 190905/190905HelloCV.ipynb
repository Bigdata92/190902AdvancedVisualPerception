# %% [markdown]
# <a href="https://colab.research.google.com/github/Bigdata92/190902AdvancedVisualPerception/blob/master/190905HelloCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 구글 드라이브 연동

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/Colab Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
# !ls
# Out:
# '(190805)NN_MNIST_Test_NumericalDerivative_ver1.ipynb'
# '(190808)Diabetes_RandomDataGeneration_ver2.ipynb'
# '(190808)Titanic_ver1.ipynb'
# '(190823)CNN_1conv_5X5_adam_ver1.ipynb'
#  190902VisualPerception01.ipynb
#  190903ML01.ipynb
#  190903VisualPerception02.ipynb
# '190904Activation_Function (1).ipynb'
#  190904Activation_Function.ipynb
#  190904VisualPerception01.ipynb
# '190905 (1).ipynb'
#  190905HelloCV.ipynb
#  190905.ipynb
#  3일차.zip
#  Introduction_to_convnets.ipynb
#  Python_For_DA_4.3.ipynb
#  Untitled0.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled5.ipynb
#  Untitled6.ipynb
#  Untitled7.ipynb
#  Untitled8.ipynb

# %% [markdown]
# ### 사진 다운 받아서 불러오기

# %%
import numpy as np
import cv2 as cv 
from google.colab.patches import cv2_imshow
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F299BE88860>

# %%
img = cv.imread('1.jpg')
if img is None:
  print('Image load failed!')
  exit()

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F299C6E57F0>

# %%
img1 = cv.imread('1.jpg', cv.IMREAD_GRAYSCALE)

cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F2993AC3748>

# %% [markdown]
# ### CVPR - Computer Vision Pattern Recognition
# ### graph convolution 나옴
# ### 1. Synthesizing a motion blurred
# ### 2. Synthesizing photorealistic images given an input semantic layout
# ### 3. Reconstruct a complete and textured 3D model of a person from a single image (CNN)
# ### (2D<->3D), use 2D silhouettes and 3D joints of a body pose to reconstruct 3D mesh
# ### 4. Im2Pencil: Controllable Pencil Illystration from Photographs
# ### Input(A) -> CycleGAN(B) -> Input(A') 하여 A와 A'의 차이를 작게
# ### 5. End-to-End Time-Lapse Video Synthesis from a single Outdoor Image(광원 만들어 냄)
# ### 사진 한장 놓고 GAN으로 광원 만들어 timelapse 함
# ### 6. StoryGAN : A Sequential Conditional GAN for Story Visualization
# ### Propose a new task called Story Visualization using GAN
# ### 7. Image Super-Resolution by Neural Texture Transfer(oral)
# ### Improve "RefSR" even shen irrelevant reference images are provided
# ### 8. DVC: An End-to-end Deep Video Compression Framework
# ### 10.Bag of Tricks for Image Classification with Convolutional Neural Networks
# ### 11. Fully Learnable Group Convolution for Acceleration of DNN
# ### 12. ScratchDet: Exploring to Train Single-
# ### 13. Precise Detection in Densely Packed Scenes
# ### 14. SIXray: A Large-scale Security Inspection X-ray Benchmark for Prohibited
# ### 15. Generalized Intersection over Union: A Metric and A Loss for Bounding Box Regressio
# ### 16. Bounding Box Regression with Uncertianty for Accurate Object Detection
# ### novel bounding box regression loss with uncertainty
# ### 17.
# ### End-to-end - 에러값 하나로 BackPropagation통해 weight, bias update
# ### things:countable, stuff:uncountable
# ### 19. Fast Interactive Object Annotation with Curve-GC
# ###
