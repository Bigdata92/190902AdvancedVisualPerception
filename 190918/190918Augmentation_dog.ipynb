# %% [markdown]
# <a href="https://colab.research.google.com/github/Bigdata92/190902AdvancedVisualPerception/blob/master/190918/190918Augmentation_dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls
# Out:
# test  train  validation

# %%
cd /content/gdrive/My Drive/datasets/Augmentation
# Out:
# /content/gdrive/My Drive/datasets/Augmentation

# %%
import numpy as np
import scipy
import cv2 as cv 
from google.colab.patches import cv2_imshow

location = './train/dogs/dog.0.jpg'

img1 = cv.imread(location)
# print img1.shape
if img1 is None:
 print('Image load failed!')

flip_down = np.flipud(img1)

cv2_imshow(flip_down)
cv.imwrite('./train/dogs/dog.5.jpg', flip_down)
# Out:
# <PIL.Image.Image image mode=RGB size=349x144 at 0x7FCCBC634410>
# True

# %%
import os 
location = './train/dogs/'
image_list = os.listdir(location)
print image_list
# Out:
# ['dog.0.jpg', 'dog.1.jpg', 'dog.2.jpg', 'dog.3.jpg', 'dog.4.jpg', 'dog.5.jpg', 'dog.6.jpg', 'dog.7.jpg', 'dog.8.jpg', 'dog.9.jpg']

# %%
index = np.random.choice(len(image_list), 5)
print (index)
# Out:
# [4 0 2 2 6]

# %%
from scipy import ndimage

index = np.random.choice(len(image_list), 5)

count = 0
for i in range(len(index)):
  
  location = './train/dogs/dog.{}.jpg'.format(i)
  print location 
  
  image = cv.imread(location)
  
  if i % 2 == 0: 
    image = np.flipud(image)
  elif i % 3 == 0:
    image = ndimage.rotate(image, 30)
  elif i % 5 == 0:
    image = ndimage.gaussian_filter(image, sigma=3)
    
  cv2_imshow(image) # 확인해 보려고 
  
  location = './train/dogs/dog.{}.jpg'.format((len(index)+count))
  cv.imwrite(location, image)
  count += 1
# Out:
# ./train/dogs/dog.0.jpg
# <PIL.Image.Image image mode=RGB size=349x144 at 0x7FCCBC57E110>
# ./train/dogs/dog.1.jpg
# <PIL.Image.Image image mode=RGB size=264x191 at 0x7FCCBC634650>
# ./train/dogs/dog.2.jpg
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FCCBFD4C650>
# ./train/dogs/dog.3.jpg
# <PIL.Image.Image image mode=RGB size=344x295 at 0x7FCCBC634650>
# ./train/dogs/dog.4.jpg
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FCCBFD4C650>

# %%
import os 
import as np
from keras.prer
# Out:
#   File "<ipython-input-62-6b6fe70ce9a0>", line 2
#     import as np
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### fit 100/20
# ### fit_generator 20*5

# %%
f
