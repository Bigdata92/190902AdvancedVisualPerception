# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/cifar-10-python.tar.gz

# %%
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam,SGD
import keras
from keras import layers
import matplotlib.pyplot as plt
import sys
import numpy as np
from keras.preprocessing import image

print(os.listdir("../input"))
# Out:
# Using TensorFlow backend.
# ['cifar-10-python.tar.gz']

# %%
from os import listdir, makedirs
from os.path import join, exists, expanduser

cache_dir = expanduser(join('~', '.keras'))
if not exists(cache_dir):
    makedirs(cache_dir)
datasets_dir = join(cache_dir, 'datasets') # /cifar-10-batches-py
if not exists(datasets_dir):
    makedirs(datasets_dir)


# !cp ../input/cifar-10-python.tar.gz ~/.keras/datasets/
# !ln -s  ~/.keras/datasets/cifar-10-python.tar.gz ~/.keras/datasets/cifar-10-batches-py.tar.gz
# !tar xzvf ~/.keras/datasets/cifar-10-python.tar.gz -C ~/.keras/datasets/
# Out:
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1

# %%
(X_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select a single class images (birds)
X_train = X_train[y_train.flatten() == 2]

# %%
# Input shape
img_rows = 32
img_cols = 32
channels = 3
        
img_shape = (img_rows, img_cols, channels)        
latent_dim = 100

# %%
latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# 입력을 16 × 16 크기의 128개 채널을 가진 특성 맵으로 변환합니다
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# 합성곱 층을 추가합니다
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# 32 × 32 크기로 업샘플링합니다
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# 합성곱 층을 더 추가합니다
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# 32 × 32 크기의 1개 채널을 가진 특성 맵을 생성합니다
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# 드롭아웃 층을 넣는 것이 아주 중요합니다!
x = layers.Dropout(0.4)(x)

# 분류 층
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')

# %%
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
# 데이터를 정규화합니다
X_train = X_train.reshape(
    (X_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = join(datasets_dir, 'gan_images')
if not os.path.exists(save_dir):
    os.mkdir(save_dir)

# %%
start = 0
for step in range(iterations):
    # 잠재 공간에서 무작위로 포인트를 샘플링합니다
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # 가짜 이미지를 디코딩합니다
    generated_images = generator.predict(random_latent_vectors)

    # 진짜 이미지와 연결합니다
    stop = start + batch_size
    real_images = X_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # 진짜와 가짜 이미지를 구분하여 레이블을 합칩니다
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # 레이블에 랜덤 노이즈를 추가합니다. 아주 중요합니다!
    labels += 0.05 * np.random.random(labels.shape)

    # discriminator를 훈련합니다
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # 잠재 공간에서 무작위로 포인트를 샘플링합니다
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # 모두 “진짜 이미지"라고 레이블을 만듭니다
    misleading_targets = np.zeros((batch_size, 1))

    # generator를 훈련합니다(gan 모델에서 discriminator의 가중치는 동결됩니다)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(X_train) - batch_size:
      start = 0

    # 중간 중간 저장하고 그래프를 그립니다
    if step % 100 == 0:
        # 모델 가중치를 저장합니다
        gan.save_weights('gan.h5')

        # 측정 지표를 출력합니다
        print('스텝 %s에서 판별자 손실: %s' % (step, d_loss))
        print('스텝 %s에서 적대적 손실: %s' % (step, a_loss))

        # 생성된 이미지 하나를 저장합니다
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # 비교를 위해 진짜 이미지 하나를 저장합니다
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# /opt/conda/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 스텝 0에서 판별자 손실: 0.7009579
# 스텝 0에서 적대적 손실: 0.71721476
# /opt/conda/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 스텝 100에서 판별자 손실: 0.39022407
# 스텝 100에서 적대적 손실: 2.5347083
# 스텝 200에서 판별자 손실: 0.7387022
# 스텝 200에서 적대적 손실: 0.7483626
# 스텝 300에서 판별자 손실: 0.68755114
# 스텝 300에서 적대적 손실: 0.74095774
# 스텝 400에서 판별자 손실: 0.7028309
# 스텝 400에서 적대적 손실: 0.7317533
# 스텝 500에서 판별자 손실: 0.7036191
# 스텝 500에서 적대적 손실: 0.7462341
# 스텝 600에서 판별자 손실: 0.6906878
# 스텝 600에서 적대적 손실: 0.7347051
# 스텝 700에서 판별자 손실: 0.6807788
# 스텝 700에서 적대적 손실: 1.1523235
# 스텝 800에서 판별자 손실: 0.6827
# 스텝 800에서 적대적 손실: 0.74235094
# 스텝 900에서 판별자 손실: 0.6949689
# 스텝 900에서 적대적 손실: 0.7494531
# 스텝 1000에서 판별자 손실: 0.69410974
# 스텝 1000에서 적대적 손실: 0.7479707
# 스텝 1100에서 판별자 손실: 0.6949485
# 스텝 1100에서 적대적 손실: 0.7419747
# 스텝 1200에서 판별자 손실: 0.69571054
# 스텝 1200에서 적대적 손실: 0.7393371
# 스텝 1300에서 판별자 손실: 0.699788
# 스텝 1300에서 적대적 손실: 0.74027795
# 스텝 1400에서 판별자 손실: 0.69518715
# 스텝 1400에서 적대적 손실: 0.76195246
# 스텝 1500에서 판별자 손실: 0.7409222
# 스텝 1500에서 적대적 손실: 1.4016993
# 스텝 1600에서 판별자 손실: 0.6912493
# 스텝 1600에서 적대적 손실: 0.7542503
# 스텝 1700에서 판별자 손실: 0.68594044
# 스텝 1700에서 적대적 손실: 0.74088085
# 스텝 1800에서 판별자 손실: 0.70198834
# 스텝 1800에서 적대적 손실: 0.7336854
# 스텝 1900에서 판별자 손실: 0.70320165
# 스텝 1900에서 적대적 손실: 0.7698251
# 스텝 2000에서 판별자 손실: 0.68658924
# 스텝 2000에서 적대적 손실: 0.7331005
# 스텝 2100에서 판별자 손실: 0.69774806
# 스텝 2100에서 적대적 손실: 0.87186384
# 스텝 2200에서 판별자 손실: 0.71592027
# 스텝 2200에서 적대적 손실: 0.7547249
# 스텝 2300에서 판별자 손실: 0.6970986
# 스텝 2300에서 적대적 손실: 0.9057062
# 스텝 2400에서 판별자 손실: 0.6930072
# 스텝 2400에서 적대적 손실: 0.73883295
# 스텝 2500에서 판별자 손실: 0.69972587
# 스텝 2500에서 적대적 손실: 0.76593673
# 스텝 2600에서 판별자 손실: 0.6985366
# 스텝 2600에서 적대적 손실: 0.75341296
# 스텝 2700에서 판별자 손실: 1.37761
# 스텝 2700에서 적대적 손실: 0.78208196
# 스텝 2800에서 판별자 손실: 0.7028847
# 스텝 2800에서 적대적 손실: 0.74787366
# 스텝 2900에서 판별자 손실: 0.69605374
# 스텝 2900에서 적대적 손실: 0.70711976
# 스텝 3000에서 판별자 손실: 0.69829905
# 스텝 3000에서 적대적 손실: 0.7357071
# 스텝 3100에서 판별자 손실: 0.6880865
# 스텝 3100에서 적대적 손실: 0.74161756
# 스텝 3200에서 판별자 손실: 0.6887579
# 스텝 3200에서 적대적 손실: 0.75659645
# 스텝 3300에서 판별자 손실: 0.7000038
# 스텝 3300에서 적대적 손실: 0.7893818
# 스텝 3400에서 판별자 손실: 0.68226856
# 스텝 3400에서 적대적 손실: 0.74128234
# 스텝 3500에서 판별자 손실: 0.6923434
# 스텝 3500에서 적대적 손실: 0.71810526
# 스텝 3600에서 판별자 손실: 0.69399345
# 스텝 3600에서 적대적 손실: 0.7269354
# 스텝 3700에서 판별자 손실: 0.6945365
# 스텝 3700에서 적대적 손실: 0.7683887
# 스텝 3800에서 판별자 손실: 0.6883913
# 스텝 3800에서 적대적 손실: 0.7294754
# 스텝 3900에서 판별자 손실: 0.71642447
# 스텝 3900에서 적대적 손실: 0.7265865
# 스텝 4000에서 판별자 손실: 0.6945778
# 스텝 4000에서 적대적 손실: 0.71478635
# 스텝 4100에서 판별자 손실: 0.70444906
# 스텝 4100에서 적대적 손실: 0.74745953
# 스텝 4200에서 판별자 손실: 0.69707865
# 스텝 4200에서 적대적 손실: 0.87900865
# 스텝 4300에서 판별자 손실: 0.69112134
# 스텝 4300에서 적대적 손실: 0.7264595
# 스텝 4400에서 판별자 손실: 0.6873765
# 스텝 4400에서 적대적 손실: 0.7186278
# 스텝 4500에서 판별자 손실: 0.683547
# 스텝 4500에서 적대적 손실: 0.76028407
# 스텝 4600에서 판별자 손실: 0.6915345
# 스텝 4600에서 적대적 손실: 0.9594041
# 스텝 4700에서 판별자 손실: 0.69998705
# 스텝 4700에서 적대적 손실: 0.76131415
# 스텝 4800에서 판별자 손실: 0.6988981
# 스텝 4800에서 적대적 손실: 0.75584424
# 스텝 4900에서 판별자 손실: 0.9129616
# 스텝 4900에서 적대적 손실: 2.146695
# 스텝 5000에서 판별자 손실: 0.7260091
# 스텝 5000에서 적대적 손실: 0.67839605
# 스텝 5100에서 판별자 손실: 0.7023568
# 스텝 5100에서 적대적 손실: 0.7540543
# 스텝 5200에서 판별자 손실: 0.6879655
# 스텝 5200에서 적대적 손실: 0.7417458
# 스텝 5300에서 판별자 손실: 0.6977623
# 스텝 5300에서 적대적 손실: 0.75161016
# 스텝 5400에서 판별자 손실: 0.6982899
# 스텝 5400에서 적대적 손실: 0.766884
# 스텝 5500에서 판별자 손실: 0.69726866
# 스텝 5500에서 적대적 손실: 0.7526167
# 스텝 5600에서 판별자 손실: 0.70216763
# 스텝 5600에서 적대적 손실: 0.7603921
# 스텝 5700에서 판별자 손실: 0.7029955
# 스텝 5700에서 적대적 손실: 0.71963185
# 스텝 5800에서 판별자 손실: 0.7774456
# 스텝 5800에서 적대적 손실: 0.88934165
# 스텝 5900에서 판별자 손실: 0.70111537
# 스텝 5900에서 적대적 손실: 0.7735217
# 스텝 6000에서 판별자 손실: 0.67805374
# 스텝 6000에서 적대적 손실: 0.7817214
# 스텝 6100에서 판별자 손실: 0.6887717
# 스텝 6100에서 적대적 손실: 0.7607559
# 스텝 6200에서 판별자 손실: 0.69639796
# 스텝 6200에서 적대적 손실: 0.7967864
# 스텝 6300에서 판별자 손실: 0.68797827
# 스텝 6300에서 적대적 손실: 0.6973193
# 스텝 6400에서 판별자 손실: 0.684549
# 스텝 6400에서 적대적 손실: 0.7889391
# 스텝 6500에서 판별자 손실: 0.68154263
# 스텝 6500에서 적대적 손실: 0.6812512
# 스텝 6600에서 판별자 손실: 0.688579
# 스텝 6600에서 적대적 손실: 0.82166976
# 스텝 6700에서 판별자 손실: 0.6934791
# 스텝 6700에서 적대적 손실: 0.878126
# 스텝 6800에서 판별자 손실: 0.6832743
# 스텝 6800에서 적대적 손실: 0.7404731
# 스텝 6900에서 판별자 손실: 0.6781963
# 스텝 6900에서 적대적 손실: 0.7358781
# 스텝 7000에서 판별자 손실: 0.68399066
# 스텝 7000에서 적대적 손실: 0.7019334
# 스텝 7100에서 판별자 손실: 0.7397952
# 스텝 7100에서 적대적 손실: 0.73806894
# 스텝 7200에서 판별자 손실: 0.6940299
# 스텝 7200에서 적대적 손실: 0.888436
# 스텝 7300에서 판별자 손실: 0.7180093
# 스텝 7300에서 적대적 손실: 0.7654518
# 스텝 7400에서 판별자 손실: 0.7312962
# 스텝 7400에서 적대적 손실: 0.9552477
# 스텝 7500에서 판별자 손실: 0.6895706
# 스텝 7500에서 적대적 손실: 0.8798587
# 스텝 7600에서 판별자 손실: 0.66362983
# 스텝 7600에서 적대적 손실: 0.77653635
# 스텝 7700에서 판별자 손실: 0.6676731
# 스텝 7700에서 적대적 손실: 0.7516271
# 스텝 7800에서 판별자 손실: 0.66630185
# 스텝 7800에서 적대적 손실: 0.8769962
# 스텝 7900에서 판별자 손실: 1.3137157
# 스텝 7900에서 적대적 손실: 1.2068496
# 스텝 8000에서 판별자 손실: 0.77027225
# 스텝 8000에서 적대적 손실: 0.7184166
# 스텝 8100에서 판별자 손실: 0.68919766
# 스텝 8100에서 적대적 손실: 0.84346503
# 스텝 8200에서 판별자 손실: 0.6662734
# 스텝 8200에서 적대적 손실: 0.82742727
# 스텝 8300에서 판별자 손실: 0.78316975
# 스텝 8300에서 적대적 손실: 1.2352155
# 스텝 8400에서 판별자 손실: 0.6635535
# 스텝 8400에서 적대적 손실: 0.8042734
# 스텝 8500에서 판별자 손실: 0.66580635
# 스텝 8500에서 적대적 손실: 0.8173935
# 스텝 8600에서 판별자 손실: 0.6707359
# 스텝 8600에서 적대적 손실: 0.5878228
# 스텝 8700에서 판별자 손실: 0.62370694
# 스텝 8700에서 적대적 손실: 0.93267155
# 스텝 8800에서 판별자 손실: 0.66730195
# 스텝 8800에서 적대적 손실: 0.738015
# 스텝 8900에서 판별자 손실: 0.7920772
# 스텝 8900에서 적대적 손실: 1.1281526
# 스텝 9000에서 판별자 손실: 0.68338203
# 스텝 9000에서 적대적 손실: 0.70984197
# 스텝 9100에서 판별자 손실: 0.6444178
# 스텝 9100에서 적대적 손실: 0.7068811
# 스텝 9200에서 판별자 손실: 0.6738095
# 스텝 9200에서 적대적 손실: 0.7475728
# 스텝 9300에서 판별자 손실: 0.665666
# 스텝 9300에서 적대적 손실: 0.83031905
# 스텝 9400에서 판별자 손실: 0.5816606
# 스텝 9400에서 적대적 손실: 1.2233976
# 스텝 9500에서 판별자 손실: 0.70165634
# 스텝 9500에서 적대적 손실: 0.7215649
# 스텝 9600에서 판별자 손실: 0.6830446
# 스텝 9600에서 적대적 손실: 0.8132006
# 스텝 9700에서 판별자 손실: 0.67265093
# 스텝 9700에서 적대적 손실: 0.86647236
# 스텝 9800에서 판별자 손실: 0.6900474
# 스텝 9800에서 적대적 손실: 0.94570494
# 스텝 9900에서 판별자 손실: 0.66434014
# 스텝 9900에서 적대적 손실: 0.8854017

# %%
s=X_train[:40]
s = 0.5 * s + 0.5
f, ax = plt.subplots(5,8, figsize=(16,10))
for i, img in enumerate(s):
        ax[i//8, i%8].imshow(img)
        ax[i//8, i%8].axis('off')
        
plt.show()

# %%
noise = np.random.normal(size=(40, latent_dim))
generated_images = generator.predict(noise)
generated_images = 0.5 * generated_images + 0.5
f, ax = plt.subplots(5,8, figsize=(16,10))
for i, img in enumerate(generated_images):
        ax[i//8, i%8].imshow(img)
        ax[i//8, i%8].axis('off')
        
plt.show()
